# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoPauloSampaio/code-01-introducao/blob/master/code_01_Introdu%C3%A7%C3%A3oJOAOPAULO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício
#
# Olá! Vamos praticar alguns comandos através de exercícios _hands on_.

# %%
#imports
from numpy import array
import numpy as np
import numpy
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Procurem três tipos de imagens:
#
# *   Uma imagem preto e branco;
# *   Uma imagem em tons de cinza;
# *   Uma imagem colorida, de extensão `jpg`.
#
# Salvem as imagens no GoogleDrive, e carreguem no script. Crie as seguintes variáveis: `imagem_pb`, `imagem_cinza` e `imagem_color`, carregue e "plote" as duas imagens.

# %%
from google.colab import drive
drive.mount('/content/drive')

imagem_color = Image.open('/content/drive/My Drive/Colab Notebooks/starcolor.jpg')
imagem_cinza = Image.open('/content/drive/My Drive/Colab Notebooks/stargray.jpg')
imagem_pb = Image.open('/content/drive/My Drive/Colab Notebooks/starpb.jpg')

plt.imshow(imagem_color)
plt.show()

plt.imshow(imagem_cinza)
plt.show()

plt.imshow(imagem_pb)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Realize uma análise exploratória dos dados das imagens, e responda as questões abaixo:

# %%
# escreva os códigos necessários para análise aqui, inclua pontos de códigos entre
# as questões, assim como incluam plots, tabelas, o que for necessário 

#img_arrGray = array(imagem_cinza)
#img_arrColor = array(imagem_color)
#img_arrPb = array(imagem_pb)

#print(img_arrGray)
#print(img_arrColor)
#print(img_arrPb)
imagem_pb_arr = array(imagem_pb)
imagem_cinza_arr = array(imagem_cinza)
imagem_color_arr = array(imagem_color)

#imagem_cinza_arr
#imagem_pb_arr
red = imagem_color_arr[:,:,0]
green = imagem_color_arr[:,:,1]
blue = imagem_color_arr[:,:,2]

# %% [markdown]
# Qual o menor e maior valor das imagens:
# *   [pb]:1, 1
# *   [cinza]:186, 33
# *   [color]:
#     * [R] 255, 229
#     * [G] 255, 241
#     * [B] 255, 237

# %% [markdown]
# Qual o valor da média imagens:
#
# *   [pb]: 1
# *   [cinza]: 105
# *   [color]:
#     * [R]244
#     * [G]251
#     * [B]248

# %% [markdown]
# Qual o valor da mediana imagens:
#
# *   [pb]:1
# *   [cinza]:109
# *   [color]:
#     * [R] 242
#     * [G] 248
#     * [B] 246

# %% [markdown]
# Inverta os valores de `imagem_pb`, e "plote" a figura.

# %%
imagem_pb_arr = 255 - imagem_pb_arr
plt.imshow(imagem_pb_arr)

# %% [markdown]
# Faça a média entre os valores `R`, `G` e `B` de `image_color`, e gere uma nova imagem e plot o resultado.

# %%
imagem_color_arr = np.array(imagem_color) 
imagem_color_arr = np.mean(imagem_color_arr, axis=(2)) 
plt.imshow(imagem_color_arr) 
plt.show()
